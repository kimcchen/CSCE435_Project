# %%
import sys
sys.path.append("/scratch/group/csce435-f24/python-3.10.4/lib/python3.10/site-packages")
sys.path.append("/scratch/group/csce435-f24/thicket")
from glob import glob

import matplotlib.pyplot as plt
import pandas as pd

import thicket as th

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)
# Out:
# Warning: Roundtrip module could not be loaded. Requires jupyter notebook version <= 7.x.

# %% [markdown]
# Read all files

# %%
#1_trial is a name of a folder containing the cali files, you may create a folder with a different name and replace the folder name here
tk = th.Thicket.from_caliperreader(glob("cali_files_cm/*.cali"))
# Out:
# (1/2) Reading Files: 100%|██████████| 12/12 [00:01<00:00, 11.93it/s]
# (2/2) Creating Thicket: 100%|██████████| 11/11 [00:00<00:00, 27.40it/s]

# %% [markdown]
# View Calltree

# %%
print(tk.tree(metric_column="Avg time/rank"))
# Out:
#   _____ _     _      _        _
#  |_   _| |__ (_) ___| | _____| |_
#    | | | '_ \| |/ __| |/ / _ \ __|
#    | | | | | | | (__|   <  __/ |_
#    |_| |_| |_|_|\___|_|\_\___|\__|  v2024.1.0
#
# 4.781 main
# ├─ 0.055 MPI_Barrier
# ├─ 0.000 MPI_Comm_dup
# ├─ 0.000 MPI_Finalize
# ├─ 0.000 MPI_Finalized
# ├─ 0.000 MPI_Init
# ├─ 0.000 MPI_Initialized
# ├─ 0.160 comm
# │  ├─ 0.147 comm_large
# │  │  ├─ 0.023 MPI_Isend
# │  │  ├─ 0.122 MPI_Recv
# │  │  └─ 0.000 MPI_Wait
# │  └─ 0.013 comm_small
# │     ├─ 0.012 MPI_Recv
# │     └─ 0.001 MPI_Send
# ├─ 2.939 comp
# │  ├─ 2.621 comp_large
# │  └─ 0.318 comp_small
# ├─ 0.035 correctness_check
# │  ├─ 0.020 MPI_Recv
# │  └─ 0.000 MPI_Send
# └─ 0.014 data_init_X
#
# Legend (Metric: Avg time/rank Min: 0.00 Max: 4.78 indices: {'profile': 511818267})
# █ 4.30 - 4.78
# █ 3.35 - 4.30
# █ 2.39 - 3.35
# █ 1.43 - 2.39
# █ 0.48 - 1.43
# █ 0.00 - 0.48
#
# name User code    ◀  Only in left graph    ▶  Only in right graph

# %%
tk.metadata
# Out:
#            cali.caliper.version  mpi.world.size  \
# profile
# 511818267                2.11.0              32
# 879462861                2.11.0              16
# 938826661                2.11.0              16
# 1201377666               2.11.0              16
# 1396076755               2.11.0              16
# 1408158097               2.11.0              32
# 1592076283               2.11.0              32
# 2518251085               2.11.0              16
# 3075120669               2.11.0              32
# 3107138611               2.11.0              16
# 3258257171               2.11.0              32
# 3530001097               2.11.0              32
#
#                                                  spot.metrics  \
# profile
# 511818267   min#inclusive#sum#time.duration,max#inclusive#...
# 879462861   min#inclusive#sum#time.duration,max#inclusive#...
# 938826661   min#inclusive#sum#time.duration,max#inclusive#...
# 1201377666  min#inclusive#sum#time.duration,max#inclusive#...
# 1396076755  min#inclusive#sum#time.duration,max#inclusive#...
# 1408158097  min#inclusive#sum#time.duration,max#inclusive#...
# 1592076283  min#inclusive#sum#time.duration,max#inclusive#...
# 2518251085  min#inclusive#sum#time.duration,max#inclusive#...
# 3075120669  min#inclusive#sum#time.duration,max#inclusive#...
# 3107138611  min#inclusive#sum#time.duration,max#inclusive#...
# 3258257171  min#inclusive#sum#time.duration,max#inclusive#...
# 3530001097  min#inclusive#sum#time.duration,max#inclusive#...
#
#            spot.timeseries.metrics  spot.format.version  \
# profile
# 511818267                                             2
# 879462861                                             2
# 938826661                                             2
# 1201377666                                            2
# 1396076755                                            2
# 1408158097                                            2
# 1592076283                                            2
# 2518251085                                            2
# 3075120669                                            2
# 3107138611                                            2
# 3258257171                                            2
# 3530001097                                            2
#
#                                                  spot.options  spot.channels  \
# profile
# 511818267   time.variance,profile.mpi,node.order,region.co...  regionprofile
# 879462861   time.variance,profile.mpi,node.order,region.co...  regionprofile
# 938826661   time.variance,profile.mpi,node.order,region.co...  regionprofile
# 1201377666  time.variance,profile.mpi,node.order,region.co...  regionprofile
# 1396076755  time.variance,profile.mpi,node.order,region.co...  regionprofile
# 1408158097  time.variance,profile.mpi,node.order,region.co...  regionprofile
# 1592076283  time.variance,profile.mpi,node.order,region.co...  regionprofile
# 2518251085  time.variance,profile.mpi,node.order,region.co...  regionprofile
# 3075120669  time.variance,profile.mpi,node.order,region.co...  regionprofile
# 3107138611  time.variance,profile.mpi,node.order,region.co...  regionprofile
# 3258257171  time.variance,profile.mpi,node.order,region.co...  regionprofile
# 3530001097  time.variance,profile.mpi,node.order,region.co...  regionprofile
#
#            cali.channel spot:cache_misses spot:node.order  \
# profile
# 511818267          spot              true            true
# 879462861          spot              true            true
# 938826661          spot              true            true
# 1201377666         spot              true            true
# 1396076755         spot              true            true
# 1408158097         spot              true            true
# 1592076283         spot              true            true
# 2518251085         spot              true            true
# 3075120669         spot              true            true
# 3107138611         spot              true            true
# 3258257171         spot              true            true
# 3530001097         spot              true            true
#
#                                      spot:output spot:profile.mpi  \
# profile
# 511818267   cali_files_cm/p32-a524288x256-2.cali             true
# 879462861   cali_files_cm/p16-a524288x512-1.cali             true
# 938826661   cali_files_cm/p16-a524288x512-0.cali             true
# 1201377666  cali_files_cm/p16-a524288x256-0.cali             true
# 1396076755  cali_files_cm/p16-a524288x256-1.cali             true
# 1408158097  cali_files_cm/p32-a524288x512-1.cali             true
# 1592076283  cali_files_cm/p32-a524288x256-0.cali             true
# 2518251085  cali_files_cm/p16-a524288x256-2.cali             true
# 3075120669  cali_files_cm/p32-a524288x512-2.cali             true
# 3107138611  cali_files_cm/p16-a524288x512-2.cali             true
# 3258257171  cali_files_cm/p32-a524288x512-0.cali             true
# 3530001097  cali_files_cm/p32-a524288x256-1.cali             true
#
#            spot:region.count spot:time.exclusive spot:time.variance  \
# profile
# 511818267               true                true               true
# 879462861               true                true               true
# 938826661               true                true               true
# 1201377666              true                true               true
# 1396076755              true                true               true
# 1408158097              true                true               true
# 1592076283              true                true               true
# 2518251085              true                true               true
# 3075120669              true                true               true
# 3107138611              true                true               true
# 3258257171              true                true               true
# 3530001097              true                true               true
#
#             launchdate                                          libraries  \
# profile
# 511818267   1729823977  [/scratch/group/csce435-f24/Caliper/caliper/li...
# 879462861   1729823981  [/scratch/group/csce435-f24/Caliper/caliper/li...
# 938826661   1729823977  [/scratch/group/csce435-f24/Caliper/caliper/li...
# 1201377666  1729823958  [/scratch/group/csce435-f24/Caliper/caliper/li...
# 1396076755  1729823958  [/scratch/group/csce435-f24/Caliper/caliper/li...
# 1408158097  1729823997  [/scratch/group/csce435-f24/Caliper/caliper/li...
# 1592076283  1729823977  [/scratch/group/csce435-f24/Caliper/caliper/li...
# 2518251085  1729823954  [/scratch/group/csce435-f24/Caliper/caliper/li...
# 3075120669  1729823998  [/scratch/group/csce435-f24/Caliper/caliper/li...
# 3107138611  1729823977  [/scratch/group/csce435-f24/Caliper/caliper/li...
# 3258257171  1729823996  [/scratch/group/csce435-f24/Caliper/caliper/li...
# 3530001097  1729823977  [/scratch/group/csce435-f24/Caliper/caliper/li...
#
#                                         cmdline cluster    algorithm  \
# profile
# 511818267   [./column_sort_mpi, 524288, 256, 2]       c  column_sort
# 879462861   [./column_sort_mpi, 524288, 512, 1]       c  column_sort
# 938826661   [./column_sort_mpi, 524288, 512, 0]       c  column_sort
# 1201377666  [./column_sort_mpi, 524288, 256, 0]       c  column_sort
# 1396076755  [./column_sort_mpi, 524288, 256, 1]       c  column_sort
# 1408158097  [./column_sort_mpi, 524288, 512, 1]       c  column_sort
# 1592076283  [./column_sort_mpi, 524288, 256, 0]       c  column_sort
# 2518251085  [./column_sort_mpi, 524288, 256, 2]       c  column_sort
# 3075120669  [./column_sort_mpi, 524288, 512, 2]       c  column_sort
# 3107138611  [./column_sort_mpi, 524288, 512, 2]       c  column_sort
# 3258257171  [./column_sort_mpi, 524288, 512, 0]       c  column_sort
# 3530001097  [./column_sort_mpi, 524288, 256, 1]       c  column_sort
#
#            programming_model data_type  size_of_data_type  input_size  \
# profile
# 511818267                mpi       int                  4   134217728
# 879462861                mpi       int                  4   268435456
# 938826661                mpi       int                  4   268435456
# 1201377666               mpi       int                  4   134217728
# 1396076755               mpi       int                  4   134217728
# 1408158097               mpi       int                  4   268435456
# 1592076283               mpi       int                  4   134217728
# 2518251085               mpi       int                  4   134217728
# 3075120669               mpi       int                  4   268435456
# 3107138611               mpi       int                  4   268435456
# 3258257171               mpi       int                  4   268435456
# 3530001097               mpi       int                  4   134217728
#
#                input_type  num_procs scalability  group_num  \
# profile
# 511818267   ReverseSorted         32      strong          2
# 879462861          Random         16      strong          2
# 938826661          Sorted         16      strong          2
# 1201377666         Sorted         16      strong          2
# 1396076755         Random         16      strong          2
# 1408158097         Random         32      strong          2
# 1592076283         Sorted         32      strong          2
# 2518251085  ReverseSorted         16      strong          2
# 3075120669  ReverseSorted         32      strong          2
# 3107138611  ReverseSorted         16      strong          2
# 3258257171         Sorted         32      strong          2
# 3530001097         Random         32      strong          2
#
#            implementation_source
# profile
# 511818267            handwritten
# 879462861            handwritten
# 938826661            handwritten
# 1201377666           handwritten
# 1396076755           handwritten
# 1408158097           handwritten
# 1592076283           handwritten
# 2518251085           handwritten
# 3075120669           handwritten
# 3107138611           handwritten
# 3258257171           handwritten
# 3530001097           handwritten

# %% [markdown]
# Group Performance data by `matrix_size` in the Thicket metadata table.

# %%
tk.metadata_column_to_perfdata("num_procs", overwrite=True)
tk.metadata_column_to_perfdata("input_size", overwrite=True)
tk.metadata_column_to_perfdata("input_type", overwrite=True)

# tk.dataframe = tk.dataframe.reset_index().set_index(
#     ["node", "num_procs", "matrix_size"]
# ).sort_index()

tk.dataframe = tk.dataframe.reset_index().set_index(
    ["node", "num_procs", "input_size", "input_type"]
).sort_index()

tk.dataframe.head()
# Out:
#                                                                             profile  \
# node                                 num_procs input_size input_type
# {'name': 'main', 'type': 'function'} 16        134217728  Random         1396076755
#                                                           ReverseSorted  2518251085
#                                                           Sorted         1201377666
#                                                268435456  Random          879462861
#                                                           ReverseSorted  3107138611
#
#                                                                          nid  \
# node                                 num_procs input_size input_type
# {'name': 'main', 'type': 'function'} 16        134217728  Random         1.0
#                                                           ReverseSorted  1.0
#                                                           Sorted         1.0
#                                                268435456  Random         1.0
#                                                           ReverseSorted  1.0
#
#                                                                           spot.channel  \
# node                                 num_procs input_size input_type
# {'name': 'main', 'type': 'function'} 16        134217728  Random         regionprofile
#                                                           ReverseSorted  regionprofile
#                                                           Sorted         regionprofile
#                                                268435456  Random         regionprofile
#                                                           ReverseSorted  regionprofile
#
#                                                                          Min time/rank  \
# node                                 num_procs input_size input_type
# {'name': 'main', 'type': 'function'} 16        134217728  Random              7.598541
#                                                           ReverseSorted       7.494828
#                                                           Sorted              5.881192
#                                                268435456  Random             14.718656
#                                                           ReverseSorted      14.158567
#
#                                                                          Max time/rank  \
# node                                 num_procs input_size input_type
# {'name': 'main', 'type': 'function'} 16        134217728  Random              7.598583
#                                                           ReverseSorted       7.496539
#                                                           Sorted              5.882832
#                                                268435456  Random             14.720752
#                                                           ReverseSorted      14.160339
#
#                                                                          Avg time/rank  \
# node                                 num_procs input_size input_type
# {'name': 'main', 'type': 'function'} 16        134217728  Random              7.598566
#                                                           ReverseSorted       7.495655
#                                                           Sorted              5.882695
#                                                268435456  Random             14.719695
#                                                           ReverseSorted      14.159381
#
#                                                                          Total time  \
# node                                 num_procs input_size input_type
# {'name': 'main', 'type': 'function'} 16        134217728  Random         121.577060
#                                                           ReverseSorted  119.930472
#                                                           Sorted          94.123118
#                                                268435456  Random         235.515117
#                                                           ReverseSorted  226.550100
#
#                                                                          Min L1 misses/rank (exc)  \
# node                                 num_procs input_size input_type
# {'name': 'main', 'type': 'function'} 16        134217728  Random                        1059331.0
#                                                           ReverseSorted                 1071445.0
#                                                           Sorted                        1084092.0
#                                                268435456  Random                        1062626.0
#                                                           ReverseSorted                 1068441.0
#
#                                                                          Max L1 misses/rank (exc)  \
# node                                 num_procs input_size input_type
# {'name': 'main', 'type': 'function'} 16        134217728  Random                        1077571.0
#                                                           ReverseSorted                 1089223.0
#                                                           Sorted                        1107558.0
#                                                268435456  Random                        1087242.0
#                                                           ReverseSorted                 1095211.0
#
#                                                                          Avg L1 misses/rank (exc)  \
# node                                 num_procs input_size input_type
# {'name': 'main', 'type': 'function'} 16        134217728  Random                     1.068551e+06
#                                                           ReverseSorted              1.081719e+06
#                                                           Sorted                     1.093117e+06
#                                                268435456  Random                     1.073270e+06
#                                                           ReverseSorted              1.078493e+06
#
#                                                                          Total L1 misses (exc)  \
# node                                 num_procs input_size input_type
# {'name': 'main', 'type': 'function'} 16        134217728  Random                    17096822.0
#                                                           ReverseSorted             17307506.0
#                                                           Sorted                    17489878.0
#                                                268435456  Random                    17172326.0
#                                                           ReverseSorted             17255885.0
#
#                                                                          Min L2 misses/rank (exc)  \
# node                                 num_procs input_size input_type
# {'name': 'main', 'type': 'function'} 16        134217728  Random                         356314.0
#                                                           ReverseSorted                  367327.0
#                                                           Sorted                         371440.0
#                                                268435456  Random                         355041.0
#                                                           ReverseSorted                  368096.0
#
#                                                                          Max L2 misses/rank (exc)  \
# node                                 num_procs input_size input_type
# {'name': 'main', 'type': 'function'} 16        134217728  Random                         379017.0
#                                                           ReverseSorted                  382274.0
#                                                           Sorted                         389525.0
#                                                268435456  Random                         371302.0
#                                                           ReverseSorted                  384606.0
#
#                                                                          Avg L2 misses/rank (exc)  \
# node                                 num_procs input_size input_type
# {'name': 'main', 'type': 'function'} 16        134217728  Random                      366997.5625
#                                                           ReverseSorted               374292.6875
#                                                           Sorted                      379054.9375
#                                                268435456  Random                      364392.5000
#                                                           ReverseSorted               376076.4375
#
#                                                                          Total L2 misses (exc)  \
# node                                 num_procs input_size input_type
# {'name': 'main', 'type': 'function'} 16        134217728  Random                     5871961.0
#                                                           ReverseSorted              5988683.0
#                                                           Sorted                     6064879.0
#                                                268435456  Random                     5830280.0
#                                                           ReverseSorted              6017223.0
#
#                                                                          Min L1 misses/rank  \
# node                                 num_procs input_size input_type
# {'name': 'main', 'type': 'function'} 16        134217728  Random                 45413321.0
#                                                           ReverseSorted          45001138.0
#                                                           Sorted                 50593637.0
#                                                268435456  Random                 89689009.0
#                                                           ReverseSorted          88812045.0
#
#                                                                          Max L1 misses/rank  \
# node                                 num_procs input_size input_type
# {'name': 'main', 'type': 'function'} 16        134217728  Random                 47601666.0
#                                                           ReverseSorted          48740090.0
#                                                           Sorted                 50990872.0
#                                                268435456  Random                 92615411.0
#                                                           ReverseSorted          93102743.0
#
#                                                                          Avg L1 misses/rank  \
# node                                 num_procs input_size input_type
# {'name': 'main', 'type': 'function'} 16        134217728  Random               4.568095e+07
#                                                           ReverseSorted        4.539296e+07
#                                                           Sorted               5.073698e+07
#                                                268435456  Random               9.019442e+07
#                                                           ReverseSorted        8.928985e+07
#
#                                                                          Total L1 misses  \
# node                                 num_procs input_size input_type
# {'name': 'main', 'type': 'function'} 16        134217728  Random            7.308952e+08
#                                                           ReverseSorted     7.262874e+08
#                                                           Sorted            8.117917e+08
#                                                268435456  Random            1.443111e+09
#                                                           ReverseSorted     1.428638e+09
#
#                                                                          Min L2 misses/rank  \
# node                                 num_procs input_size input_type
# {'name': 'main', 'type': 'function'} 16        134217728  Random                 36731518.0
#                                                           ReverseSorted          36106828.0
#                                                           Sorted                 38907209.0
#                                                268435456  Random                 88804737.0
#                                                           ReverseSorted          87330292.0
#
#                                                                          Max L2 misses/rank  \
# node                                 num_procs input_size input_type
# {'name': 'main', 'type': 'function'} 16        134217728  Random               1.844674e+19
#                                                           ReverseSorted        1.844674e+19
#                                                           Sorted               3.914517e+07
#                                                268435456  Random               8.976907e+07
#                                                           ReverseSorted        8.940152e+07
#
#                                                                          Avg L2 misses/rank  \
# node                                 num_procs input_size input_type
# {'name': 'main', 'type': 'function'} 16        134217728  Random               1.152922e+18
#                                                           ReverseSorted        1.152922e+18
#                                                           Sorted               3.903893e+07
#                                                268435456  Random               8.899397e+07
#                                                           ReverseSorted        8.763890e+07
#
#                                                                          Total L2 misses  \
# node                                 num_procs input_size input_type
# {'name': 'main', 'type': 'function'} 16        134217728  Random            1.844674e+19
#                                                           ReverseSorted     1.844674e+19
#                                                           Sorted            6.246229e+08
#                                                268435456  Random            1.423904e+09
#                                                           ReverseSorted     1.402222e+09
#
#                                                                          Variance time/rank  \
# node                                 num_procs input_size input_type
# {'name': 'main', 'type': 'function'} 16        134217728  Random                   0.000000
#                                                           ReverseSorted            0.000001
#                                                           Sorted                   0.000000
#                                                268435456  Random                   0.000001
#                                                           ReverseSorted            0.000001
#
#                                                                          Min time/rank (exc)  \
# node                                 num_procs input_size input_type
# {'name': 'main', 'type': 'function'} 16        134217728  Random                    0.743049
#                                                           ReverseSorted             0.907677
#                                                           Sorted                    0.832114
#                                                268435456  Random                    0.759991
#                                                           ReverseSorted             0.882971
#
#                                                                          Max time/rank (exc)  \
# node                                 num_procs input_size input_type
# {'name': 'main', 'type': 'function'} 16        134217728  Random                    0.749437
#                                                           ReverseSorted             0.914646
#                                                           Sorted                    0.835488
#                                                268435456  Random                    0.767995
#                                                           ReverseSorted             0.890888
#
#                                                                          Avg time/rank (exc)  \
# node                                 num_procs input_size input_type
# {'name': 'main', 'type': 'function'} 16        134217728  Random                    0.748088
#                                                           ReverseSorted             0.910383
#                                                           Sorted                    0.833906
#                                                268435456  Random                    0.766103
#                                                           ReverseSorted             0.888835
#
#                                                                          Total time (exc)  \
# node                                 num_procs input_size input_type
# {'name': 'main', 'type': 'function'} 16        134217728  Random                11.969408
#                                                           ReverseSorted         14.566127
#                                                           Sorted                13.342493
#                                                268435456  Random                12.257647
#                                                           ReverseSorted         14.221355
#
#                                                                          Calls/rank (min)  \
# node                                 num_procs input_size input_type
# {'name': 'main', 'type': 'function'} 16        134217728  Random                      NaN
#                                                           ReverseSorted               NaN
#                                                           Sorted                      NaN
#                                                268435456  Random                      NaN
#                                                           ReverseSorted               NaN
#
#                                                                          Calls/rank (avg)  \
# node                                 num_procs input_size input_type
# {'name': 'main', 'type': 'function'} 16        134217728  Random                      NaN
#                                                           ReverseSorted               NaN
#                                                           Sorted                      NaN
#                                                268435456  Random                      NaN
#                                                           ReverseSorted               NaN
#
#                                                                          Calls/rank (max)  \
# node                                 num_procs input_size input_type
# {'name': 'main', 'type': 'function'} 16        134217728  Random                      NaN
#                                                           ReverseSorted               NaN
#                                                           Sorted                      NaN
#                                                268435456  Random                      NaN
#                                                           ReverseSorted               NaN
#
#                                                                          Calls/rank (total)  \
# node                                 num_procs input_size input_type
# {'name': 'main', 'type': 'function'} 16        134217728  Random                        NaN
#                                                           ReverseSorted                 NaN
#                                                           Sorted                        NaN
#                                                268435456  Random                        NaN
#                                                           ReverseSorted                 NaN
#
#                                                                          name
# node                                 num_procs input_size input_type
# {'name': 'main', 'type': 'function'} 16        134217728  Random         main
#                                                           ReverseSorted  main
#                                                           Sorted         main
#                                                268435456  Random         main
#                                                           ReverseSorted  main

# %%
# Define common variables
# processes = [2, 4, 8, 16, 32, 64, 128, 256, 512, 1024]
# exps = [16, 18, 20, 22, 24, 26, 28
processes = [16, 32]
exps = [27, 28]
input_types = ["Sorted", "Random", "ReverseSorted"]
# matrix_sizes = [128, 1024, 8192]
# master_plots = ['whole_computation', 'master_initialization', 'master_send_recieve']
save = True

# %%
# Change font size for all plots
plt.rcParams.update({"font.size": 20})

# %%
def plot_mpl(dfs, title, xlabel, ylabel, legend=None, markers=["o"], save=False):
    fig = plt.figure(figsize=(15,7))
    ax = fig.add_subplot(1, 1, 1)
    for df, marker in zip(dfs, markers):
        ax.plot(
            df,
            marker=marker,
            markersize=10
        )
    ax.set_title(title)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    if legend is not None:
        ax.legend(legend)
    plt.xscale("log", base=2)
    plt.xticks(processes)
    ax.set_xticklabels(processes)
    if save:
        plt.savefig(f"plots_cm/{title}.jpg", bbox_inches='tight')
#     plt.close(fig)
    plt.show()
    return fig, ax

def plot_mpl_notdf(x, y, title, xlabel, ylabel, legend=None, markers=["o"], save=False):
    fig = plt.figure(figsize=(15,7))
    ax = fig.add_subplot(1, 1, 1)
    ax.plot(x, y)
    ax.set_title(title)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    if legend is not None:
        ax.legend(legend)
    plt.xscale("log", base=2)
    plt.xticks(x)
    ax.set_xticklabels(x)
    if save:
        plt.savefig(f"plots/{title}.jpg", bbox_inches='tight')
#     plt.close(fig)
    plt.show()

# %% [markdown]
# Plot Cache Misses

# %%
# # print(tk.dataframe.loc[node, "Min time/rank"].unstack(level=["input_size", "input_type"])[size])

for node in tk.graph.traverse():
#     if node.frame['name'] == 'main' or "MPI" in node.frame['name']:
#     if node.frame['name'] not in plots:
    if "main" not in node.frame['name']:
        continue
    
    name = node.frame['name']
#     if "data_init_X" in name:
#         name = 'data_init_runtime'
    
#     for exp in exps:
#         size = int(2**exp)
#         dfs = []
#         legend = []
#         for input_type in input_types:
#             dfs.append(tk.dataframe.loc[node, "Total L1 misses"].unstack(level=["input_size", "input_type"])[size][input_type])
#             legend.append(f"L1 misses - {input_type}")
#             dfs.append(tk.dataframe.loc[node, "Total L2 misses"].unstack(level=["input_size", "input_type"])[size][input_type])
#             legend.append(f"L2 misses - {input_type}")
            
#         markers = ["o"] * len(dfs)
#         plot_mpl(
#             dfs,
#             f"Cache Misses for 2^{exp} elements", 
#             "Number of Processes", 
#             "Number of Cache Misses (1e19)",
#             legend,
#             markers,
#             save=False
#         )

    dfs = []
    legend = []
    for cache in ["Total L1 misses", "Total L2 misses"]:
        dfs = []
        legend = []
        for input_type in input_types:
            for exp in exps:
                size = int(2**exp)
                dfs.append(tk.dataframe.loc[node, cache].unstack(level=["input_size", "input_type"])[size][input_type])
                legend.append(f"{input_type} 2^{exp}")
            
        markers = ["o"] * len(dfs)
        plot_mpl(
            dfs,
            f"{cache}",
            "Number of Processes", 
            "Number of Cache Misses",
            legend,
            markers,
            save=save
        )

# %%
ljusts = [20, 10, 25, 0]

for node in tk.graph.traverse():
#     if node.frame['name'] == 'main' or "MPI" in node.frame['name']:
#     if node.frame['name'] not in plots:
    if "main" not in node.frame['name']:
        continue
    
    name = node.frame['name']
    if "data_init_X" in name:
        name = 'data_init_runtime'
    
    for cache in ["Total L1 misses", "Total L2 misses"]:
        rows = []
        for input_type in input_types:
            for numProcs in [16, 32]:
                row = []
                row.append(input_type)
                row.append(numProcs)
                for exp in exps:
                    size = int(2**exp)
                    row.append(tk.dataframe.loc[node, cache].unstack(level=["input_size", "input_type"])[size][input_type][numProcs])
#                     row.append(tk.dataframe.loc[node, "Total L2 misses"].unstack(level=["input_size", "input_type"])[size][input_type][numProcs])

                rows.append(row)
             
    
        print(f"{cache}")
        print("---------------------------------------")
        print("Input Type       Processes    2^27 Cache Misses        2^28 Cache Misses")
        for row in rows:
            printRow = ""
            for i in range(len(row)):
                printRow += str(row[i]).ljust(ljusts[i])
            print(printRow)
        print()
# Out:
# Total L1 misses
# ---------------------------------------
# Input Type       Processes    2^27 Cache Misses        2^28 Cache Misses
# Sorted              16        811791728.0              1594399523.0
# Sorted              32        780249028.0              1625094156.0
# Random              16        730895166.0              1443110733.0
# Random              32        708958382.0              1496485981.0
# ReverseSorted       16        726287410.0              1428637530.0
# ReverseSorted       32        703665262.0              1482751552.0
#
# Total L2 misses
# ---------------------------------------
# Input Type       Processes    2^27 Cache Misses        2^28 Cache Misses
# Sorted              16        624622937.0              1484686042.0
# Sorted              32        3.68934881479404e+19     9.22337203696782e+19
# Random              16        1.844674407430018e+19    1423903586.0
# Random              32        1.844674407420208e+19    1.8446744074821054e+19
# ReverseSorted       16        1.8446744074291778e+19   1402222333.0
# ReverseSorted       32        491269106.0              3.689348814852167e+19
